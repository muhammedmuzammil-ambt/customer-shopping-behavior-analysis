# %%
import pandas as pd
df=pd.read_csv("C:/Users/muzammil/OneDrive/Desktop/power Bi proj/customer_shopping_behavior.csv")

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  ...  Discount Applied  \
# 0       Kentucky    L       Gray  Winter  ...               Yes
# 1          Maine    L     Maroon  Winter  ...               Yes
# 2  Massachusetts    S     Maroon  Spring  ...               Yes
# 3   Rhode Island    M     Maroon  Spring  ...               Yes
# 4         Oregon    M  Turquoise  Spring  ...               Yes
#
#   Promo Code Used Previous Purchases Payment Method Frequency of Purchases  \
# 0             Yes                 14          Venmo            Fortnightly
# 1             Yes                  2           Cash            Fortnightly
# 2             Yes                 23    Credit Card                 Weekly
# 3             Yes                 49         PayPal                 Weekly
# 4             Yes                 31         PayPal               Annually
#
#    Unnamed: 18 Season.1 Average Review Rtaing   Unnamed: 21 Spender Tier
# 0          NaN  Spring             3.788956434          NaN          NaN
# 1          NaN   Summer            3.788956434          NaN          NaN
# 2          NaN     Fall            3.726800847          NaN          NaN
# 3          NaN   Winter            3.732610939          NaN          NaN
# 4          NaN      NaN                    NaN          NaN          NaN
#
# [5 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3863 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
#  14  Promo Code Used         3900 non-null   object
#  15  Previous Purchases      3900 non-null   int64
#  16  Payment Method          3900 non-null   object
#  17  Frequency of Purchases  3900 non-null   object
#  18  Unnamed: 18             0 non-null      float64
#  19  Season.1                8 non-null      object
#  20  Average Review Rtaing   8 non-null      object
#  21  Unnamed: 21             0 non-null      float64
#  22  Spender Tier            0 non-null      float64
# dtypes: float64(4), int64(4), object(15)
# memory usage: 700.9+ KB

# %%
 df.describe(include='all')
# Out:
#         Customer ID          Age Gender Item Purchased  Category  \
# count   3900.000000  3900.000000   3900           3900      3900
# unique          NaN          NaN      2             25         4
# top             NaN          NaN   Male         Blouse  Clothing
# freq            NaN          NaN   2652            171      1737
# mean    1950.500000    44.068462    NaN            NaN       NaN
# std     1125.977353    15.207589    NaN            NaN       NaN
# min        1.000000    18.000000    NaN            NaN       NaN
# 25%      975.750000    31.000000    NaN            NaN       NaN
# 50%     1950.500000    44.000000    NaN            NaN       NaN
# 75%     2925.250000    57.000000    NaN            NaN       NaN
# max     3900.000000    70.000000    NaN            NaN       NaN
#
#         Purchase Amount (USD) Location  Size  Color  Season  ...  \
# count             3900.000000     3900  3900   3900    3900  ...
# unique                    NaN       50     4     25       4  ...
# top                       NaN  Montana     M  Olive  Spring  ...
# freq                      NaN       96  1755    177     999  ...
# mean                59.764359      NaN   NaN    NaN     NaN  ...
# std                 23.685392      NaN   NaN    NaN     NaN  ...
# min                 20.000000      NaN   NaN    NaN     NaN  ...
# 25%                 39.000000      NaN   NaN    NaN     NaN  ...
# 50%                 60.000000      NaN   NaN    NaN     NaN  ...
# 75%                 81.000000      NaN   NaN    NaN     NaN  ...
# max                100.000000      NaN   NaN    NaN     NaN  ...
#
#         Discount Applied Promo Code Used Previous Purchases Payment Method  \
# count               3900            3900        3900.000000           3900
# unique                 2               2                NaN              6
# top                   No              No                NaN         PayPal
# freq                2223            2223                NaN            677
# mean                 NaN             NaN          25.351538            NaN
# std                  NaN             NaN          14.447125            NaN
# min                  NaN             NaN           1.000000            NaN
# 25%                  NaN             NaN          13.000000            NaN
# 50%                  NaN             NaN          25.000000            NaN
# 75%                  NaN             NaN          38.000000            NaN
# max                  NaN             NaN          50.000000            NaN
#
#        Frequency of Purchases  Unnamed: 18 Season.1 Average Review Rtaing   \
# count                    3900          0.0        8                      8
# unique                      7          NaN        8                      5
# top            Every 3 Months          NaN  Spring                    1053
# freq                      584          NaN        1                      3
# mean                      NaN          NaN      NaN                    NaN
# std                       NaN          NaN      NaN                    NaN
# min                       NaN          NaN      NaN                    NaN
# 25%                       NaN          NaN      NaN                    NaN
# 50%                       NaN          NaN      NaN                    NaN
# 75%                       NaN          NaN      NaN                    NaN
# max                       NaN          NaN      NaN                    NaN
#
#         Unnamed: 21 Spender Tier
# count           0.0          0.0
# unique          NaN          NaN
# top             NaN          NaN
# freq            NaN          NaN
# mean            NaN          NaN
# std             NaN          NaN
# min             NaN          NaN
# 25%             NaN          NaN
# 50%             NaN          NaN
# 75%             NaN          NaN
# max             NaN          NaN
#
# [11 rows x 23 columns]

# %%
df.isnull().sum()
# Out:
# Customer ID                  0
# Age                          0
# Gender                       0
# Item Purchased               0
# Category                     0
# Purchase Amount (USD)        0
# Location                     0
# Size                         0
# Color                        0
# Season                       0
# Review Rating               37
# Subscription Status          0
# Shipping Type                0
# Discount Applied             0
# Promo Code Used              0
# Previous Purchases           0
# Payment Method               0
# Frequency of Purchases       0
# Unnamed: 18               3900
# Season.1                  3892
# Average Review Rtaing     3892
# Unnamed: 21               3900
# Spender Tier              3900
# dtype: int64

# %%
# Imputing missing values in Review Rating column with the median rating of the product category

df['Review Rating'] = df.groupby('Category')['Review Rating'].transform(lambda x: x.fillna(x.median()))

# %%
df.isnull().sum()
# Out:
# Customer ID                  0
# Age                          0
# Gender                       0
# Item Purchased               0
# Category                     0
# Purchase Amount (USD)        0
# Location                     0
# Size                         0
# Color                        0
# Season                       0
# Review Rating                0
# Subscription Status          0
# Shipping Type                0
# Discount Applied             0
# Promo Code Used              0
# Previous Purchases           0
# Payment Method               0
# Frequency of Purchases       0
# Unnamed: 18               3900
# Season.1                  3892
# Average Review Rtaing     3892
# Unnamed: 21               3900
# Spender Tier              3900
# dtype: int64

# %%
# Renaming columns according to snake casing for better readability and documentation

df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ','_')
df = df.rename(columns={'purchase_amount_(usd)':'purchase_amount'})

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases', 'unnamed:_18', 'season.1',
#        'average_review_rtaing_', 'unnamed:_21', 'spender_tier'],
#       dtype='object')

# %%
# create a new column age_group
labels = ['Young Adult', 'Adult', 'Middle-aged', 'Senior']
df['age_group'] = pd.qcut(df['age'], q=4, labels = labels)

# %%
df[['age','age_group']].head(10)
# Out:
#    age    age_group
# 0   55  Middle-aged
# 1   19  Young Adult
# 2   50  Middle-aged
# 3   21  Young Adult
# 4   45  Middle-aged
# 5   46  Middle-aged
# 6   63       Senior
# 7   27  Young Adult
# 8   26  Young Adult
# 9   57  Middle-aged

# %%
# create new column purchase_frequency_days

frequency_mapping = {
    'Fortnightly': 14,
    'Weekly': 7,
    'Monthly': 30,
    'Quarterly': 90,
    'Bi-Weekly': 14,
    'Annually': 365,
    'Every 3 Months': 90
}

df['purchase_frequency_days'] = df['frequency_of_purchases'].map(frequency_mapping)

# %%
df[['purchase_frequency_days','frequency_of_purchases']].head(10)
# Out:
#    purchase_frequency_days frequency_of_purchases
# 0                       14            Fortnightly
# 1                       14            Fortnightly
# 2                        7                 Weekly
# 3                        7                 Weekly
# 4                      365               Annually
# 5                        7                 Weekly
# 6                       90              Quarterly
# 7                        7                 Weekly
# 8                      365               Annually
# 9                       90              Quarterly

# %%
df[['discount_applied','promo_code_used']].head(10)
# Out:
#   discount_applied promo_code_used
# 0              Yes             Yes
# 1              Yes             Yes
# 2              Yes             Yes
# 3              Yes             Yes
# 4              Yes             Yes
# 5              Yes             Yes
# 6              Yes             Yes
# 7              Yes             Yes
# 8              Yes             Yes
# 9              Yes             Yes

# %%
(df['discount_applied'] == df['promo_code_used']).all()
# Out:
# True

# %%
df = df.drop('promo_code_used', axis=1)

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'previous_purchases', 'payment_method',
#        'frequency_of_purchases', 'unnamed:_18', 'season.1',
#        'average_review_rtaing_', 'unnamed:_21', 'spender_tier', 'age_group',
#        'purchase_frequency_days'],
#       dtype='object')

# %%
# !pip install psycopg2-binary sqlalchemy
# Out:
# Requirement already satisfied: psycopg2-binary in c:\users\muzammil\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.9.12)
# Collecting sqlalchemy
#   Using cached sqlalchemy-2.0.52-cp311-cp311-win_amd64.whl.metadata (9.9 kB)
# Requirement already satisfied: greenlet>=1 in c:\users\muzammil\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sqlalchemy) (3.5.5)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\muzammil\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sqlalchemy) (4.14.1)
# Using cached sqlalchemy-2.0.52-cp311-cp311-win_amd64.whl (2.2 MB)
# Installing collected packages: sqlalchemy
# Successfully installed sqlalchemy-2.0.52
# [notice] A new release of pip is available: 25.2 -> 26.2.1
# [notice] To update, run: C:\Users\muzammil\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from sqlalchemy import create_engine
from sqlalchemy.engine import URL

connection_url = URL.create(
    "postgresql+psycopg2",
    username="postgres",
    password="XXXXXXXXX",
    host="localhost",
    port=5432,
    database="costomer_behavior"
)

engine = create_engine(connection_url)

with engine.connect() as connection:
    print("PostgreSQL connection successful!")
# Out:
# PostgreSQL connection successful!

# %%
table_name = "customer"

df.to_sql(
    table_name,
    engine,
    if_exists="replace",
    index=False
)

print("Data successfully loaded into PostgreSQL!")
# Out:
# Data successfully loaded into PostgreSQL!
